# %% [markdown]
# ### Implicit Bias Correlations

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import pyreadstat

# %%
skin_df_04 = pd.read_spss('data/skin_tone_data/Skin Tone IAT.public.2004.sav')

# %%
skin_df_04.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14256 entries, 0 to 14255
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   session_id                 14256 non-null  float64
#  1   session_status             14256 non-null  object
#  2   study_name                 14256 non-null  object
#  3   date                       14256 non-null  float64
#  4   month                      14256 non-null  float64
#  5   day                        14256 non-null  float64
#  6   year                       14256 non-null  float64
#  7   hour                       14256 non-null  float64
#  8   weekday                    14256 non-null  float64
#  9   age                        7495 non-null   float64
#  10  num                        14256 non-null  object
#  11  sex                        14256 non-null  category
#  12  ethnic                     7432 non-null   category
# ...

# %%
skin_05 = pd.read_spss('data/skin_tone_data/Skin Tone IAT.public.2005.sav')

# %%
skin_05.count()
# Out:
# session_id                 58570
# session_status             58570
# study_name                 58570
# date                       58570
# month                      58570
#                            ...
# CountyNo                   58570
# MSAName                    58570
# user_id                    58570
# previous_session_id            0
# previous_session_schema    58570
# Length: 74, dtype: int64

# %%
comp_05 = skin_05.loc[skin_05['session_status'] == 'C']
comp_05.count()
# Out:
# session_id                 37419
# session_status             37419
# study_name                 37419
# date                       37419
# month                      37419
#                            ...
# CountyNo                   37419
# MSAName                    37419
# user_id                    37419
# previous_session_id            0
# previous_session_schema    37419
# Length: 74, dtype: int64

# %%
skin_06 = pd.read_spss('data/skin_tone_data/Skin Tone IAT.public.2006.sav')

# %%
skin_06.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126302 entries, 0 to 126301
# Columns: 335 entries, session_id to previous_session_schema
# dtypes: category(273), float64(49), object(13)
# memory usage: 92.8+ MB

# %%
for col in skin_06.columns: 
    print(col)
# Out:
# session_id
# session_status
# study_name
# date
# month
# day
# year
# hour
# weekday
# age
# num
# sex
# ethnic
# raceomb
# ethnicityomb
# D_biep.LightSkin_Good_all
# Mn_RT_all_3467
# N_3467
# PCT_error_3467
# Order
# Side_Light_34
# Side_Good_34
# Stimuli
# pct_300
# pct_400
# pct_2K
# pct_3K
# pct_4K
# att
# att_5
# att_7
# tdark
# tlight
# myskin
# preferskin
# admission
# customs
# employ
# taxi
# D_biep.LightSkin_Good_36
# D_biep.LightSkin_Good_47
# Mn_RT_all_3
# Mn_RT_all_4
# Mn_RT_all_6
# Mn_RT_all_7
# SD_all_3
# SD_all_4
# SD_all_6
# SD_all_7
# N_3
# N_4
# N_5
# N_6
# N_7
# Mn_RT_correct_3
# Mn_RT_correct_4
# Mn_RT_correct_6
# Mn_RT_correct_7
# SD_correct_3
# SD_correct_4
# SD_correct_6
# SD_correct_7
# N_ERROR_3
# N_ERROR_4
# N_ERROR_6
# N_ERROR_7
# countrycit
# countryres
# edu
# edu_14
# major
# occupation
# politicalid
# politicalid_6
# politicalid_7
# STATE
# MSANo
# CountyNo
# MSAName
# religion
# religionid
# q2a
# q2b
# q2c
# q2d
# q3a
# q3b
# q3c
# q4
# bfia1
# ...

# %%
skin_05.head()
# Out:
#    session_id session_status study_name          date  month  day    year  \
# 0   1472886.0              C  Demo.Skin  1.332392e+10    1.0  1.0  2005.0
# 1   1472888.0              C  Demo.Skin  1.332392e+10    1.0  1.0  2005.0
# 2   1472988.0                 Demo.Skin  1.332396e+10    1.0  1.0  2005.0
# 3   1473003.0                 Demo.Skin  1.332396e+10    1.0  1.0  2005.0
# 4   1473005.0              C  Demo.Skin  1.332396e+10    1.0  1.0  2005.0
#
#    hour  weekday   age  ...                      major politicalid  \
# 0   1.0      7.0  35.0  ...                   Business         1.0
# 1   1.0      7.0  18.0  ...                        NaN         6.0
# 2  11.0      7.0   NaN  ...                        NaN         NaN
# 3  12.0      7.0   NaN  ...                        NaN         NaN
# 4  12.0      7.0  28.0  ...  Visual or performing arts         4.0
#
#            politicalid_6           STATE             MSANo  CountyNo  \
# ...

# %% [markdown]
# Need a sample size for power calculation -- how many data points should I be considering to see if the average response time has shifted from 2004 to 2020? Get the mean from 2004 for the tests I want, for the whole population of test-takers first for maybe 4 tests. (Weapons, Race, Skin Tone, Sexuality, Gender / Career?) Are dems or republicans changing more?

# %%
skin_05.mean(axis=1)
# Out:
# 0        2.835192e+08
# 1        2.776127e+08
# 2        1.665679e+09
# 3        1.665680e+09
# 4        2.776135e+08
#              ...
# 58565    2.783078e+08
# 58566    1.669845e+09
# 58567    1.113230e+09
# 58568    3.036086e+08
# 58569    2.783078e+08
# Length: 58570, dtype: float64

# %%
skin_df_20 = pd.read_spss('data/skin_tone_data/Skin IAT.public.2020.sav')

# %%
skin_comp_split = skin_df_20.groupby('session_status')
